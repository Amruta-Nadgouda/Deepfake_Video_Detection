# %% [markdown]
# In this notebook we load the saved ResNext101 trained model (using ResNext101_ModelTrain) and predict on the DFDC test dataset.

# %%
# Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install face_recognition library
# !pip3 install face_recognition
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 22 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=deef5b3dd34ae7147368e672a5515023a50d9c5f431d18c36d25da0e805809d8
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
# Import required libraries
import torch
import torchvision
from torch import nn
from torchvision import models, transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import face_recognition
import time
import sys

# %%
sm = nn.Softmax()

def predict(model,img):
  """
  This function takes the video and converts it into logits and normalizes the
  logits using softmax() which then generates probabilties of the video being
  fake or real
  """
  fmap,logits = model(img.to('cuda'))
  logits = sm(logits)
  _,prediction = torch.max(logits,1)
  confidence = logits[:,int(prediction.item())].item()*100
  print('confidence of prediction:',confidence)
  return [int(prediction.item()),confidence]

# %%
class Model(nn.Module):
  """
  Base class for all neural network modules. Our models subclass this class.
  Use Model to load the saved trained model in the next step
  """
    def __init__(self, num_classes,latent_dim= 2048, lstm_layers=1 , hidden_dim = 2048, bidirectional = False):
        super(Model, self).__init__()
        model = models.resnext101_32x8d(pretrained = True)
        self.model = nn.Sequential(*list(model.children())[:-2])
        self.lstm = nn.LSTM(latent_dim,hidden_dim, lstm_layers,  bidirectional)
        self.relu = nn.LeakyReLU()
        self.dp = nn.Dropout(0.4)
        self.linear1 = nn.Linear(2048,num_classes)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
    def forward(self, x):
        batch_size,seq_length, c, h, w = x.shape
        x = x.view(batch_size * seq_length, c, h, w)
        fmap = self.model(x)
        x = self.avgpool(fmap)
        x = x.view(batch_size,seq_length,2048)
        x_lstm,_ = self.lstm(x,None)
        return fmap,self.dp(self.linear1(x_lstm[:,-1,:]))

# %%
class validation_dataset(Dataset):
  """
  this class accepts preprocessed video dataset as input, extracts the faces from
  each of the video, recognizes the faces and stacks the extracted frames together
  """
    def __init__(self,video_names,sequence_length = 60,transform = None):
        self.video_names = video_names
        self.transform = transform
        self.count = sequence_length
    def __len__(self):
        return len(self.video_names)
    def __getitem__(self,idx):
        video_path = self.video_names[idx]
        frames = []
        a = int(100/self.count)
        first_frame = np.random.randint(0,a)      
        for i,frame in enumerate(self.frame_extract(video_path)):
            faces = face_recognition.face_locations(frame)
            try:
              top,right,bottom,left = faces[0]
              frame = frame[top:bottom,left:right,:]
            except:
              pass
            frames.append(self.transform(frame))
            if(len(frames) == self.count):
              break
        frames = torch.stack(frames)
        frames = frames[:self.count]
        return frames.unsqueeze(0)
    def frame_extract(self,path):
      vidObj = cv2.VideoCapture(path) 
      success = 1
      while success:
          success, image = vidObj.read()
          if success:
              yield image

# %%
# importing glob to return all file paths that match a specific pattern
import glob

# provide the path to the folder containing the preprocessed test files
video_files =  glob.glob('/content/drive/MyDrive/Deepfake/data/test/faces_test/*.mp4')
# printing the number of video files
print("Number of video files:",len(video_files))

# read the labels.csv into a df
labels = pd.read_csv('/content/drive/MyDrive/Deepfake/data/test/labels.csv')
# Out:
# No. of video files: 4768

# %%
# transform the images
im_size = 112
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

train_transforms = transforms.Compose([transforms.ToPILImage(),
                                       transforms.Resize((im_size,im_size)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean,std)])

video_dataset = validation_dataset(video_files,sequence_length = 10,transform = train_transforms)
# provide the path to the saved trained model
path_to_model = '/content/drive/MyDrive/Deepfake/data/checkpoints/resnext101_16k.pt'
# create an instance of Model class and load the trained model
model = Model(2).cuda()
model.load_state_dict(torch.load(path_to_model))
# sets the model in evaluation mode
model.eval()
# Out:
# Downloading: "https://download.pytorch.org/models/resnext101_32x8d-8ba56ff5.pth" to /root/.cache/torch/hub/checkpoints/resnext101_32x8d-8ba56ff5.pth
#   0%|          | 0.00/340M [00:00<?, ?B/s]
# Model(
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (lstm): LSTM(2048, 2048, bias=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (dp): Dropout(p=0.4, inplace=False)
#   (linear1): Linear(in_features=2048, out_features=2, bias=True)
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
# )

# %%
# predicting on the preprocessed test files
pred = []
conf = []
video_names = []
vcount = 0

for i in range(0,len(video_files)):
  print(video_files[i])
  prediction = predict(model,video_dataset[i])
  video_names.append(video_files)
  pred.append(prediction[0])
  conf.append(prediction[1])
  vcount = vcount + 1
  if prediction[0] == 1:
    print("REAL")
  else:
    print("FAKE")

  print("No. of videos processed", vcount)
# Out:
# /content/drive/MyDrive/Deepfake/data/test/faces_test/chsbgqykzl.mp4
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   """
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ydvcpnvczh.mp4
# confidence of prediction: 99.99247789382935
# REAL
# No. of videos processed 3519
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xqwcmnfnbm.mp4
# confidence of prediction: 99.9895453453064
# REAL
# No. of videos processed 3520
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lhndytetmf.mp4
# confidence of prediction: 99.98353719711304
# REAL
# No. of videos processed 3521
# /content/drive/MyDrive/Deepfake/data/test/faces_test/prtlvwzqcw.mp4
# confidence of prediction: 98.91737699508667
# FAKE
# No. of videos processed 3522
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xvvmrwsrql.mp4
# confidence of prediction: 99.99520778656006
# REAL
# No. of videos processed 3523
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fiicezasqh.mp4
# confidence of prediction: 77.25841403007507
# REAL
# No. of videos processed 3524
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yohedlvirr.mp4
# confidence of prediction: 66.91681146621704
# FAKE
# No. of videos processed 3525
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vqexoifqju.mp4
# confidence of prediction: 99.74688291549683
# REAL
# No. of videos processed 3526
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hptqyaigdk.mp4
# confidence of prediction: 99.99551773071289
# REAL
# No. of videos processed 3527
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hcjcbqaxqa.mp4
# confidence of prediction: 99.99105930328369
# REAL
# No. of videos processed 3528
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sfqdprsuqs.mp4
# confidence of prediction: 99.98396635055542
# REAL
# No. of videos processed 3529
# /content/drive/MyDrive/Deepfake/data/test/faces_test/liriwkdlda.mp4
# confidence of prediction: 99.99346733093262
# REAL
# No. of videos processed 3530
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gizslvhjgg.mp4
# confidence of prediction: 99.97838139533997
# REAL
# No. of videos processed 3531
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fpjckvphaa.mp4
# confidence of prediction: 99.99265670776367
# REAL
# No. of videos processed 3532
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wohbmubnyx.mp4
# confidence of prediction: 99.99288320541382
# REAL
# No. of videos processed 3533
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yowjpeqnef.mp4
# confidence of prediction: 99.99426603317261
# REAL
# No. of videos processed 3534
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dxvibsbhad.mp4
# confidence of prediction: 99.99604225158691
# REAL
# No. of videos processed 3535
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sxhkfzldpx.mp4
# confidence of prediction: 82.1034848690033
# FAKE
# No. of videos processed 3536
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lxldenkvcj.mp4
# confidence of prediction: 99.99264478683472
# REAL
# No. of videos processed 3537
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tilahrdnti.mp4
# confidence of prediction: 99.98564720153809
# REAL
# No. of videos processed 3538
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jjjlkcbihw.mp4
# confidence of prediction: 99.99113082885742
# REAL
# No. of videos processed 3539
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qpljawqcvi.mp4
# confidence of prediction: 99.71269965171814
# REAL
# No. of videos processed 3540
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vktaplbcrs.mp4
# confidence of prediction: 99.99610185623169
# REAL
# No. of videos processed 3541
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aqtauyhhoh.mp4
# confidence of prediction: 99.97501969337463
# REAL
# No. of videos processed 3542
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ojvebysgtq.mp4
# confidence of prediction: 99.97034668922424
# REAL
# No. of videos processed 3543
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mpmydljkph.mp4
# confidence of prediction: 95.58579921722412
# REAL
# No. of videos processed 3544
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pyfgldtcyd.mp4
# confidence of prediction: 68.47951412200928
# FAKE
# No. of videos processed 3545
# /content/drive/MyDrive/Deepfake/data/test/faces_test/veotbhrbez.mp4
# confidence of prediction: 99.98437166213989
# REAL
# No. of videos processed 3546
# /content/drive/MyDrive/Deepfake/data/test/faces_test/utdjoiqdef.mp4
# confidence of prediction: 99.9762237071991
# REAL
# No. of videos processed 3547
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lbwjisijzi.mp4
# confidence of prediction: 97.36821055412292
# REAL
# No. of videos processed 3548
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nlmeiezkpq.mp4
# confidence of prediction: 99.9887228012085
# REAL
# No. of videos processed 3549
# /content/drive/MyDrive/Deepfake/data/test/faces_test/llfapmbblg.mp4
# confidence of prediction: 99.81185793876648
# REAL
# No. of videos processed 3550
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tjmnetvpck.mp4
# confidence of prediction: 99.9305009841919
# REAL
# No. of videos processed 3551
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zuntdmpxqn.mp4
# confidence of prediction: 99.90339279174805
# REAL
# No. of videos processed 3552
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lrrjplfpfg.mp4
# confidence of prediction: 99.99281167984009
# REAL
# No. of videos processed 3553
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bwoccqzwxf.mp4
# confidence of prediction: 99.99536275863647
# REAL
# No. of videos processed 3554
# /content/drive/MyDrive/Deepfake/data/test/faces_test/faugjugqed.mp4
# confidence of prediction: 99.94891881942749
# REAL
# No. of videos processed 3555
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nnfzadlnkm.mp4
# confidence of prediction: 99.9951720237732
# REAL
# No. of videos processed 3556
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ogvrzukyxd.mp4
# confidence of prediction: 99.99384880065918
# REAL
# No. of videos processed 3557
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ntshzrvogm.mp4
# confidence of prediction: 99.99327659606934
# REAL
# No. of videos processed 3558
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bhdexivpfb.mp4
# confidence of prediction: 99.98779296875
# REAL
# No. of videos processed 3559
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ybvyptrzka.mp4
# confidence of prediction: 76.10493898391724
# REAL
# No. of videos processed 3560
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xlsbxexkdc.mp4
# confidence of prediction: 67.90521144866943
# FAKE
# No. of videos processed 3561
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ijrxoenvoc.mp4
# confidence of prediction: 99.96674060821533
# REAL
# No. of videos processed 3562
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ljuuyoenbs.mp4
# confidence of prediction: 99.97318387031555
# REAL
# No. of videos processed 3563
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zovarqlaew.mp4
# confidence of prediction: 99.99159574508667
# REAL
# No. of videos processed 3564
# /content/drive/MyDrive/Deepfake/data/test/faces_test/smymimbrgt.mp4
# confidence of prediction: 99.99568462371826
# REAL
# No. of videos processed 3565
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nooejcmmeb.mp4
# confidence of prediction: 98.19698333740234
# FAKE
# No. of videos processed 3566
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iiwvpuxavc.mp4
# confidence of prediction: 99.99300241470337
# REAL
# No. of videos processed 3567
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xzaapnwflf.mp4
# confidence of prediction: 99.9804437160492
# REAL
# No. of videos processed 3568
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ycunrbmlpj.mp4
# confidence of prediction: 99.99308586120605
# REAL
# No. of videos processed 3569
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tzjrlmhqpn.mp4
# confidence of prediction: 99.96107220649719
# REAL
# No. of videos processed 3570
# /content/drive/MyDrive/Deepfake/data/test/faces_test/opvfmdwtcb.mp4
# confidence of prediction: 99.99375343322754
# REAL
# No. of videos processed 3571
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jitppyxfmh.mp4
# confidence of prediction: 99.99198913574219
# REAL
# No. of videos processed 3572
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fuyzjkkfcn.mp4
# confidence of prediction: 71.79896235466003
# FAKE
# No. of videos processed 3573
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sznsuvxrdk.mp4
# confidence of prediction: 84.62333679199219
# REAL
# No. of videos processed 3574
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tsutuebgtx.mp4
# confidence of prediction: 99.9943494796753
# REAL
# No. of videos processed 3575
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aegkavekbj.mp4
# confidence of prediction: 51.06735825538635
# REAL
# No. of videos processed 3576
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oyhpioiwdr.mp4
# confidence of prediction: 99.99171495437622
# REAL
# No. of videos processed 3577
# /content/drive/MyDrive/Deepfake/data/test/faces_test/amcqszhjsq.mp4
# confidence of prediction: 99.993896484375
# REAL
# No. of videos processed 3578
# /content/drive/MyDrive/Deepfake/data/test/faces_test/njvoudllnh.mp4
# confidence of prediction: 99.99473094940186
# REAL
# No. of videos processed 3579
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uyzqrbgwif.mp4
# confidence of prediction: 99.40908551216125
# REAL
# No. of videos processed 3580
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vylmvziaiv.mp4
# confidence of prediction: 99.97298121452332
# REAL
# No. of videos processed 3581
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zisoyrdihd.mp4
# confidence of prediction: 99.97745156288147
# REAL
# No. of videos processed 3582
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qfuewthupe.mp4
# confidence of prediction: 99.98051524162292
# FAKE
# No. of videos processed 3583
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rvojpwfoxr.mp4
# confidence of prediction: 99.99473094940186
# REAL
# No. of videos processed 3584
# /content/drive/MyDrive/Deepfake/data/test/faces_test/shjpvbaicu.mp4
# confidence of prediction: 99.77113008499146
# FAKE
# No. of videos processed 3585
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ihazzlzstk.mp4
# confidence of prediction: 99.99513626098633
# REAL
# No. of videos processed 3586
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ptipaqcrim.mp4
# confidence of prediction: 99.99431371688843
# REAL
# No. of videos processed 3587
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cgwztfzqlh.mp4
# confidence of prediction: 99.99059438705444
# REAL
# No. of videos processed 3588
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rmxskrudmc.mp4
# confidence of prediction: 99.9889612197876
# REAL
# No. of videos processed 3589
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aynopeqpyf.mp4
# confidence of prediction: 99.99494552612305
# REAL
# No. of videos processed 3590
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jgvwdwjwfi.mp4
# confidence of prediction: 99.9812662601471
# REAL
# No. of videos processed 3591
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ftqhtsnspk.mp4
# confidence of prediction: 99.98588562011719
# REAL
# No. of videos processed 3592
# /content/drive/MyDrive/Deepfake/data/test/faces_test/alxkmxynew.mp4
# confidence of prediction: 99.97581839561462
# REAL
# No. of videos processed 3593
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sjkfrlkluq.mp4
# confidence of prediction: 99.99208450317383
# REAL
# No. of videos processed 3594
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pofefdmrjt.mp4
# confidence of prediction: 99.97630715370178
# REAL
# No. of videos processed 3595
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ivribzbizo.mp4
# confidence of prediction: 93.80953311920166
# FAKE
# No. of videos processed 3596
# /content/drive/MyDrive/Deepfake/data/test/faces_test/boemzeavif.mp4
# confidence of prediction: 99.98420476913452
# REAL
# No. of videos processed 3597
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qkvsoivmrg.mp4
# confidence of prediction: 99.99052286148071
# REAL
# No. of videos processed 3598
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dvbvxxujrt.mp4
# confidence of prediction: 50.50418972969055
# FAKE
# No. of videos processed 3599
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ttbpudpuvo.mp4
# confidence of prediction: 99.97476935386658
# REAL
# No. of videos processed 3600
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uifyrmvjok.mp4
# confidence of prediction: 99.98538494110107
# REAL
# No. of videos processed 3601
# /content/drive/MyDrive/Deepfake/data/test/faces_test/twgqagwjfc.mp4
# confidence of prediction: 99.99068975448608
# REAL
# No. of videos processed 3602
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fwnfmxized.mp4
# confidence of prediction: 72.50962257385254
# REAL
# No. of videos processed 3603
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ntbcgqdfhh.mp4
# confidence of prediction: 72.11112380027771
# FAKE
# No. of videos processed 3604
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xpfoprekzb.mp4
# confidence of prediction: 99.99520778656006
# REAL
# No. of videos processed 3605
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jrcdqmgohk.mp4
# confidence of prediction: 99.87021684646606
# REAL
# No. of videos processed 3606
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lohkeoxlhy.mp4
# confidence of prediction: 99.56270456314087
# REAL
# No. of videos processed 3607
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xulyyyqtnj.mp4
# confidence of prediction: 58.8189423084259
# FAKE
# No. of videos processed 3608
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yqagtasgjq.mp4
# confidence of prediction: 68.67129802703857
# FAKE
# No. of videos processed 3609
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ojelhzdylh.mp4
# confidence of prediction: 99.98914003372192
# REAL
# No. of videos processed 3610
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gytxrbatwr.mp4
# confidence of prediction: 99.99436140060425
# REAL
# No. of videos processed 3611
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fclicrptzy.mp4
# confidence of prediction: 99.9937891960144
# REAL
# No. of videos processed 3612
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ygburrxcim.mp4
# confidence of prediction: 99.53221678733826
# REAL
# No. of videos processed 3613
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mybeyozotn.mp4
# confidence of prediction: 99.9970555305481
# REAL
# No. of videos processed 3614
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pfhpwynrax.mp4
# confidence of prediction: 99.99585151672363
# REAL
# No. of videos processed 3615
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vnxdizgsfo.mp4
# confidence of prediction: 99.98593330383301
# REAL
# No. of videos processed 3616
# /content/drive/MyDrive/Deepfake/data/test/faces_test/igakqddviu.mp4
# confidence of prediction: 50.77812671661377
# REAL
# No. of videos processed 3617
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iaqnoovycg.mp4
# confidence of prediction: 99.98987913131714
# REAL
# No. of videos processed 3618
# /content/drive/MyDrive/Deepfake/data/test/faces_test/owxuusojfe.mp4
# confidence of prediction: 74.5157539844513
# REAL
# No. of videos processed 3619
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jbtqacjelh.mp4
# confidence of prediction: 99.75121021270752
# REAL
# No. of videos processed 3620
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ioxqfixqtz.mp4
# confidence of prediction: 87.18065619468689
# REAL
# No. of videos processed 3621
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hoyqpnqsvc.mp4
# confidence of prediction: 99.98904466629028
# REAL
# No. of videos processed 3622
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vovnkvhybq.mp4
# confidence of prediction: 99.97872710227966
# REAL
# No. of videos processed 3623
# /content/drive/MyDrive/Deepfake/data/test/faces_test/birmwqpwir.mp4
# confidence of prediction: 99.93345141410828
# REAL
# No. of videos processed 3624
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gmpopozjxq.mp4
# confidence of prediction: 99.98800754547119
# REAL
# No. of videos processed 3625
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kzffhuhuzw.mp4
# confidence of prediction: 63.09575438499451
# REAL
# No. of videos processed 3626
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jfkqflrnwc.mp4
# confidence of prediction: 75.27154088020325
# FAKE
# No. of videos processed 3627
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dxigvdcusn.mp4
# confidence of prediction: 71.89451456069946
# FAKE
# No. of videos processed 3628
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wvomhglyji.mp4
# confidence of prediction: 99.89909529685974
# REAL
# No. of videos processed 3629
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fydclqaqof.mp4
# confidence of prediction: 99.94903802871704
# REAL
# No. of videos processed 3630
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cldsjiixqs.mp4
# confidence of prediction: 99.99194145202637
# REAL
# No. of videos processed 3631
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cisqkgjtsw.mp4
# confidence of prediction: 70.54076194763184
# FAKE
# No. of videos processed 3632
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yjhtgpqxyf.mp4
# confidence of prediction: 99.99281167984009
# REAL
# No. of videos processed 3633
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hayyotditz.mp4
# confidence of prediction: 91.74981117248535
# FAKE
# No. of videos processed 3634
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rlrmepakua.mp4
# confidence of prediction: 99.98998641967773
# REAL
# No. of videos processed 3635
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sttzpumjrp.mp4
# confidence of prediction: 99.95361566543579
# REAL
# No. of videos processed 3636
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nizfplnamx.mp4
# confidence of prediction: 75.86607336997986
# REAL
# No. of videos processed 3637
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wsgxngzyew.mp4
# confidence of prediction: 60.34356355667114
# REAL
# No. of videos processed 3638
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fojcfmyrvh.mp4
# confidence of prediction: 99.98327493667603
# REAL
# No. of videos processed 3639
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dvwtbzhihk.mp4
# confidence of prediction: 99.99130964279175
# REAL
# No. of videos processed 3640
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hninolobbi.mp4
# confidence of prediction: 55.71293234825134
# REAL
# No. of videos processed 3641
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qmazgkttax.mp4
# confidence of prediction: 99.96604919433594
# REAL
# No. of videos processed 3642
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oagmxogaiq.mp4
# confidence of prediction: 99.99234676361084
# REAL
# No. of videos processed 3643
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ifhrizczsq.mp4
# confidence of prediction: 99.98912811279297
# REAL
# No. of videos processed 3644
# /content/drive/MyDrive/Deepfake/data/test/faces_test/flierzeiub.mp4
# confidence of prediction: 99.98716115951538
# REAL
# No. of videos processed 3645
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qevpinwasl.mp4
# confidence of prediction: 99.99575614929199
# REAL
# No. of videos processed 3646
# /content/drive/MyDrive/Deepfake/data/test/faces_test/znpikbolfg.mp4
# confidence of prediction: 74.32447671890259
# FAKE
# No. of videos processed 3647
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oxvymddyfd.mp4
# confidence of prediction: 99.99352693557739
# REAL
# No. of videos processed 3648
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hldkwwrunq.mp4
# confidence of prediction: 57.46307969093323
# FAKE
# No. of videos processed 3649
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bbbcqjmpyu.mp4
# confidence of prediction: 98.62114191055298
# REAL
# No. of videos processed 3650
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qvvpispivk.mp4
# confidence of prediction: 99.98903274536133
# REAL
# No. of videos processed 3651
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jopdyxtmlh.mp4
# confidence of prediction: 99.97965693473816
# REAL
# No. of videos processed 3652
# /content/drive/MyDrive/Deepfake/data/test/faces_test/npxtoofnrh.mp4
# confidence of prediction: 99.96150732040405
# REAL
# No. of videos processed 3653
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vicqsuiqwa.mp4
# confidence of prediction: 99.70877766609192
# REAL
# No. of videos processed 3654
# /content/drive/MyDrive/Deepfake/data/test/faces_test/serwpgukpi.mp4
# confidence of prediction: 77.31009721755981
# FAKE
# No. of videos processed 3655
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ymfscnsfsw.mp4
# confidence of prediction: 99.99167919158936
# REAL
# No. of videos processed 3656
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cylocokdvm.mp4
# confidence of prediction: 94.47323083877563
# FAKE
# No. of videos processed 3657
# /content/drive/MyDrive/Deepfake/data/test/faces_test/adsjhmclqx.mp4
# confidence of prediction: 99.99473094940186
# REAL
# No. of videos processed 3658
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qbjpppbvfa.mp4
# confidence of prediction: 99.99359846115112
# REAL
# No. of videos processed 3659
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jtkwaaqbxn.mp4
# confidence of prediction: 99.98449087142944
# REAL
# No. of videos processed 3660
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nbxyheffez.mp4
# confidence of prediction: 99.97666478157043
# REAL
# No. of videos processed 3661
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rxytpyahdq.mp4
# confidence of prediction: 99.9864935874939
# REAL
# No. of videos processed 3662
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wnqkcgbxas.mp4
# confidence of prediction: 96.96086645126343
# REAL
# No. of videos processed 3663
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fgijfsduwq.mp4
# confidence of prediction: 55.696624517440796
# FAKE
# No. of videos processed 3664
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jhtlvsyoie.mp4
# confidence of prediction: 99.94978904724121
# REAL
# No. of videos processed 3665
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wjezovmxfx.mp4
# confidence of prediction: 99.9840259552002
# REAL
# No. of videos processed 3666
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hroyfnkoii.mp4
# confidence of prediction: 99.89851117134094
# REAL
# No. of videos processed 3667
# /content/drive/MyDrive/Deepfake/data/test/faces_test/knjbrqcgpw.mp4
# confidence of prediction: 99.96353387832642
# REAL
# No. of videos processed 3668
# /content/drive/MyDrive/Deepfake/data/test/faces_test/egmptkcwsw.mp4
# confidence of prediction: 99.99558925628662
# REAL
# No. of videos processed 3669
# /content/drive/MyDrive/Deepfake/data/test/faces_test/urhlhjhzkf.mp4
# confidence of prediction: 51.63294076919556
# REAL
# No. of videos processed 3670
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qscnfzdpen.mp4
# confidence of prediction: 99.9859094619751
# REAL
# No. of videos processed 3671
# /content/drive/MyDrive/Deepfake/data/test/faces_test/utxjzslkth.mp4
# confidence of prediction: 99.98922348022461
# REAL
# No. of videos processed 3672
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iunbwrdnxs.mp4
# confidence of prediction: 99.99366998672485
# REAL
# No. of videos processed 3673
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hhwgoorqhf.mp4
# confidence of prediction: 99.98897314071655
# REAL
# No. of videos processed 3674
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lkiiimoqwe.mp4
# confidence of prediction: 99.9805748462677
# REAL
# No. of videos processed 3675
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rnxbyxcoun.mp4
# confidence of prediction: 99.86680746078491
# REAL
# No. of videos processed 3676
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ezhwpngteq.mp4
# confidence of prediction: 99.86392855644226
# REAL
# No. of videos processed 3677
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tpmlulgsof.mp4
# confidence of prediction: 99.99706745147705
# REAL
# No. of videos processed 3678
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ahalakrkhf.mp4
# confidence of prediction: 99.96378421783447
# REAL
# No. of videos processed 3679
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jhgnqzzhcy.mp4
# confidence of prediction: 99.99397993087769
# REAL
# No. of videos processed 3680
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gnrbewlotf.mp4
# confidence of prediction: 99.77444410324097
# REAL
# No. of videos processed 3681
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ecfmocntmw.mp4
# confidence of prediction: 94.14743781089783
# REAL
# No. of videos processed 3682
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wubgkxfxns.mp4
# confidence of prediction: 87.99550533294678
# FAKE
# No. of videos processed 3683
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pkrplkkfuy.mp4
# confidence of prediction: 99.97393488883972
# REAL
# No. of videos processed 3684
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mstmhwgvvt.mp4
# confidence of prediction: 99.99116659164429
# REAL
# No. of videos processed 3685
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hfpnlezvbo.mp4
# confidence of prediction: 99.98886585235596
# REAL
# No. of videos processed 3686
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ohwlzreiwo.mp4
# confidence of prediction: 98.19151163101196
# REAL
# No. of videos processed 3687
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yzmkvwdghk.mp4
# confidence of prediction: 99.93900060653687
# REAL
# No. of videos processed 3688
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mzvczonzbq.mp4
# confidence of prediction: 93.91418099403381
# FAKE
# No. of videos processed 3689
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wevzjadwul.mp4
# confidence of prediction: 99.99045133590698
# REAL
# No. of videos processed 3690
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uvfaiqerit.mp4
# confidence of prediction: 99.99003410339355
# REAL
# No. of videos processed 3691
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lcycpfapyi.mp4
# confidence of prediction: 99.98680353164673
# REAL
# No. of videos processed 3692
# /content/drive/MyDrive/Deepfake/data/test/faces_test/axmdvjhcin.mp4
# confidence of prediction: 99.93699193000793
# REAL
# No. of videos processed 3693
# /content/drive/MyDrive/Deepfake/data/test/faces_test/whqbgdiqyz.mp4
# confidence of prediction: 99.99639987945557
# REAL
# No. of videos processed 3694
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hfalxiaikl.mp4
# confidence of prediction: 88.94277215003967
# REAL
# No. of videos processed 3695
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ufkonhkmvy.mp4
# confidence of prediction: 99.99195337295532
# REAL
# No. of videos processed 3696
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vwsxwrurup.mp4
# confidence of prediction: 99.98158812522888
# REAL
# No. of videos processed 3697
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dapkptdvvh.mp4
# confidence of prediction: 99.98834133148193
# REAL
# No. of videos processed 3698
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dcjrumugjq.mp4
# confidence of prediction: 63.300156593322754
# FAKE
# No. of videos processed 3699
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tufvaetxqx.mp4
# confidence of prediction: 99.98207688331604
# REAL
# No. of videos processed 3700
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jnajpkbbnk.mp4
# confidence of prediction: 80.3956389427185
# FAKE
# No. of videos processed 3701
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ppghreqqwn.mp4
# confidence of prediction: 99.99774694442749
# REAL
# No. of videos processed 3702
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fzssokwsow.mp4
# confidence of prediction: 99.99542236328125
# REAL
# No. of videos processed 3703
# /content/drive/MyDrive/Deepfake/data/test/faces_test/elrgzkijoq.mp4
# confidence of prediction: 99.99415874481201
# REAL
# No. of videos processed 3704
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wyigrtxkew.mp4
# confidence of prediction: 99.99257326126099
# REAL
# No. of videos processed 3705
# /content/drive/MyDrive/Deepfake/data/test/faces_test/thtjatduhw.mp4
# confidence of prediction: 99.99440908432007
# REAL
# No. of videos processed 3706
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dqgwpahsao.mp4
# confidence of prediction: 99.41396713256836
# REAL
# No. of videos processed 3707
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kbwhcpqfmr.mp4
# confidence of prediction: 99.9667763710022
# REAL
# No. of videos processed 3708
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bpjbidjbag.mp4
# confidence of prediction: 99.99182224273682
# REAL
# No. of videos processed 3709
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tbsaqpweym.mp4
# confidence of prediction: 99.99334812164307
# REAL
# No. of videos processed 3710
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cstquwjtxk.mp4
# confidence of prediction: 99.99394416809082
# REAL
# No. of videos processed 3711
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vucqjsxhkz.mp4
# confidence of prediction: 99.5582640171051
# REAL
# No. of videos processed 3712
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xtfcmarqap.mp4
# confidence of prediction: 99.97283816337585
# REAL
# No. of videos processed 3713
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lmorgkqfqe.mp4
# confidence of prediction: 99.98466968536377
# REAL
# No. of videos processed 3714
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nuuhftdxhn.mp4
# confidence of prediction: 99.99555349349976
# REAL
# No. of videos processed 3715
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kltjmxdjcd.mp4
# confidence of prediction: 99.99361038208008
# REAL
# No. of videos processed 3716
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rtuimagama.mp4
# confidence of prediction: 99.99222755432129
# REAL
# No. of videos processed 3717
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kryhzzmolv.mp4
# confidence of prediction: 99.99160766601562
# REAL
# No. of videos processed 3718
# /content/drive/MyDrive/Deepfake/data/test/faces_test/erwuheqezz.mp4
# confidence of prediction: 99.1118848323822
# REAL
# No. of videos processed 3719
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fbmuppdorf.mp4
# confidence of prediction: 99.3074893951416
# REAL
# No. of videos processed 3720
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gyewljzvpk.mp4
# confidence of prediction: 99.99438524246216
# REAL
# No. of videos processed 3721
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vdbxiqfuns.mp4
# confidence of prediction: 99.99420642852783
# REAL
# No. of videos processed 3722
# /content/drive/MyDrive/Deepfake/data/test/faces_test/opksnifiop.mp4
# confidence of prediction: 99.9937891960144
# REAL
# No. of videos processed 3723
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zikekvpjcv.mp4
# confidence of prediction: 80.14245629310608
# REAL
# No. of videos processed 3724
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oashzjuapg.mp4
# confidence of prediction: 67.46662259101868
# FAKE
# No. of videos processed 3725
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hirebcorsf.mp4
# confidence of prediction: 99.99176263809204
# REAL
# No. of videos processed 3726
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kdznfohfpt.mp4
# confidence of prediction: 96.97624444961548
# REAL
# No. of videos processed 3727
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yvmaqkqvax.mp4
# confidence of prediction: 99.99233484268188
# REAL
# No. of videos processed 3728
# /content/drive/MyDrive/Deepfake/data/test/faces_test/afjjwsmzxv.mp4
# confidence of prediction: 99.99309778213501
# REAL
# No. of videos processed 3729
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ywrzdaxyae.mp4
# confidence of prediction: 99.98902082443237
# REAL
# No. of videos processed 3730
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mxdpqgeskk.mp4
# confidence of prediction: 99.99303817749023
# REAL
# No. of videos processed 3731
# /content/drive/MyDrive/Deepfake/data/test/faces_test/brhxmyecox.mp4
# confidence of prediction: 72.06311821937561
# FAKE
# No. of videos processed 3732
# /content/drive/MyDrive/Deepfake/data/test/faces_test/efyiyeezdx.mp4
# confidence of prediction: 99.07258749008179
# REAL
# No. of videos processed 3733
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sadyvipwmt.mp4
# confidence of prediction: 99.95750784873962
# REAL
# No. of videos processed 3734
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nilqhgwdcm.mp4
# confidence of prediction: 76.1003315448761
# FAKE
# No. of videos processed 3735
# /content/drive/MyDrive/Deepfake/data/test/faces_test/armrdzmgav.mp4
# confidence of prediction: 99.99539852142334
# REAL
# No. of videos processed 3736
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vszusehcej.mp4
# confidence of prediction: 99.9956488609314
# REAL
# No. of videos processed 3737
# /content/drive/MyDrive/Deepfake/data/test/faces_test/judhrkmwsq.mp4
# confidence of prediction: 99.36898946762085
# REAL
# No. of videos processed 3738
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xktecgnpgc.mp4
# confidence of prediction: 99.92371797561646
# REAL
# No. of videos processed 3739
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fhbzrownlj.mp4
# confidence of prediction: 99.98756647109985
# REAL
# No. of videos processed 3740
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iyvarkmdmp.mp4
# confidence of prediction: 99.96211528778076
# REAL
# No. of videos processed 3741
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qwxwjffbiw.mp4
# confidence of prediction: 99.9751627445221
# REAL
# No. of videos processed 3742
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vcnsbxrvig.mp4
# confidence of prediction: 99.99537467956543
# REAL
# No. of videos processed 3743
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iibavwdpfn.mp4
# confidence of prediction: 99.96664524078369
# REAL
# No. of videos processed 3744
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ftyqwfnahu.mp4
# confidence of prediction: 99.99099969863892
# REAL
# No. of videos processed 3745
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ikiwtqtdfz.mp4
# confidence of prediction: 90.42199850082397
# REAL
# No. of videos processed 3746
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tuwzzynfpp.mp4
# confidence of prediction: 99.8689353466034
# REAL
# No. of videos processed 3747
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eueqwmtpkk.mp4
# confidence of prediction: 99.89972710609436
# REAL
# No. of videos processed 3748
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jpfoysashf.mp4
# confidence of prediction: 99.93094205856323
# FAKE
# No. of videos processed 3749
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gvstykbufc.mp4
# confidence of prediction: 99.99562501907349
# REAL
# No. of videos processed 3750
# /content/drive/MyDrive/Deepfake/data/test/faces_test/btaziuwczl.mp4
# confidence of prediction: 99.9682068824768
# REAL
# No. of videos processed 3751
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ejoyqcqbwz.mp4
# confidence of prediction: 99.98965263366699
# REAL
# No. of videos processed 3752
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rfwtnztcsj.mp4
# confidence of prediction: 99.99698400497437
# REAL
# No. of videos processed 3753
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ujbwzfrgef.mp4
# confidence of prediction: 99.96452331542969
# REAL
# No. of videos processed 3754
# /content/drive/MyDrive/Deepfake/data/test/faces_test/amimehafgd.mp4
# confidence of prediction: 99.86302852630615
# FAKE
# No. of videos processed 3755
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uxogelbplx.mp4
# confidence of prediction: 99.99161958694458
# REAL
# No. of videos processed 3756
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eppwzalgil.mp4
# confidence of prediction: 99.99078512191772
# REAL
# No. of videos processed 3757
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dubivpesyc.mp4
# confidence of prediction: 99.99254941940308
# REAL
# No. of videos processed 3758
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uyrnxxyymk.mp4
# confidence of prediction: 99.97773766517639
# REAL
# No. of videos processed 3759
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wnkgtjhszz.mp4
# confidence of prediction: 99.83862638473511
# REAL
# No. of videos processed 3760
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mhytdmqigx.mp4
# confidence of prediction: 99.99145269393921
# REAL
# No. of videos processed 3761
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vozezstbxl.mp4
# confidence of prediction: 99.99017715454102
# REAL
# No. of videos processed 3762
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rthaksosxx.mp4
# confidence of prediction: 99.99607801437378
# REAL
# No. of videos processed 3763
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xmicatcwal.mp4
# confidence of prediction: 99.98107552528381
# REAL
# No. of videos processed 3764
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hzazhwnpxa.mp4
# confidence of prediction: 61.42491102218628
# FAKE
# No. of videos processed 3765
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fqjgevcujf.mp4
# confidence of prediction: 99.99030828475952
# REAL
# No. of videos processed 3766
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xzkdlxqryz.mp4
# confidence of prediction: 97.13553190231323
# REAL
# No. of videos processed 3767
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pgabvxmbaa.mp4
# confidence of prediction: 99.99035596847534
# REAL
# No. of videos processed 3768
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dzqkxpaaqh.mp4
# confidence of prediction: 52.34549641609192
# REAL
# No. of videos processed 3769
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bjkqjwmqcq.mp4
# confidence of prediction: 99.99277591705322
# REAL
# No. of videos processed 3770
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iepacdsxov.mp4
# confidence of prediction: 99.92488026618958
# REAL
# No. of videos processed 3771
# /content/drive/MyDrive/Deepfake/data/test/faces_test/onqhlcpyxl.mp4
# confidence of prediction: 95.34200429916382
# FAKE
# No. of videos processed 3772
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uninyxgqml.mp4
# confidence of prediction: 99.99576807022095
# REAL
# No. of videos processed 3773
# /content/drive/MyDrive/Deepfake/data/test/faces_test/emxmzlyptu.mp4
# confidence of prediction: 74.50937628746033
# FAKE
# No. of videos processed 3774
# /content/drive/MyDrive/Deepfake/data/test/faces_test/upvfqvhovh.mp4
# confidence of prediction: 70.81493735313416
# FAKE
# No. of videos processed 3775
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aswwimjudg.mp4
# confidence of prediction: 99.96110796928406
# REAL
# No. of videos processed 3776
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xjxgeetoga.mp4
# confidence of prediction: 99.9737799167633
# REAL
# No. of videos processed 3777
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wcoljjbiyd.mp4
# confidence of prediction: 99.99442100524902
# REAL
# No. of videos processed 3778
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mtewbjueky.mp4
# confidence of prediction: 99.99603033065796
# REAL
# No. of videos processed 3779
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jqfrvhyrwn.mp4
# confidence of prediction: 99.87346529960632
# REAL
# No. of videos processed 3780
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rrvptxrzdg.mp4
# confidence of prediction: 98.46701622009277
# REAL
# No. of videos processed 3781
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ouflidixjk.mp4
# confidence of prediction: 99.98331069946289
# REAL
# No. of videos processed 3782
# /content/drive/MyDrive/Deepfake/data/test/faces_test/njsnfkeflw.mp4
# confidence of prediction: 99.99597072601318
# REAL
# No. of videos processed 3783
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iyhkzqtjjb.mp4
# confidence of prediction: 69.92224454879761
# FAKE
# No. of videos processed 3784
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mypihublbu.mp4
# confidence of prediction: 99.93973970413208
# REAL
# No. of videos processed 3785
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cplsozhzmj.mp4
# confidence of prediction: 99.99780654907227
# REAL
# No. of videos processed 3786
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jarlmlkfam.mp4
# confidence of prediction: 99.98801946640015
# REAL
# No. of videos processed 3787
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qlpufvofhm.mp4
# confidence of prediction: 99.7060477733612
# REAL
# No. of videos processed 3788
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xhuvhlsscj.mp4
# confidence of prediction: 99.98251795768738
# REAL
# No. of videos processed 3789
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fniyjebwat.mp4
# confidence of prediction: 99.99021291732788
# REAL
# No. of videos processed 3790
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eyrzmbdhiq.mp4
# confidence of prediction: 99.98481273651123
# REAL
# No. of videos processed 3791
# /content/drive/MyDrive/Deepfake/data/test/faces_test/yzaqslbjqi.mp4
# confidence of prediction: 99.98847246170044
# REAL
# No. of videos processed 3792
# /content/drive/MyDrive/Deepfake/data/test/faces_test/svagokzsck.mp4
# confidence of prediction: 99.98642206192017
# REAL
# No. of videos processed 3793
# /content/drive/MyDrive/Deepfake/data/test/faces_test/krhlerujcy.mp4
# confidence of prediction: 99.98774528503418
# REAL
# No. of videos processed 3794
# /content/drive/MyDrive/Deepfake/data/test/faces_test/baefqrgttz.mp4
# confidence of prediction: 99.7409999370575
# REAL
# No. of videos processed 3795
# /content/drive/MyDrive/Deepfake/data/test/faces_test/htsyfmswdb.mp4
# confidence of prediction: 99.93502497673035
# REAL
# No. of videos processed 3796
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gfasecjgtj.mp4
# confidence of prediction: 99.99145269393921
# REAL
# No. of videos processed 3797
# /content/drive/MyDrive/Deepfake/data/test/faces_test/usrimdndpz.mp4
# confidence of prediction: 99.99393224716187
# REAL
# No. of videos processed 3798
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qjkkjaptpx.mp4
# confidence of prediction: 99.9737799167633
# REAL
# No. of videos processed 3799
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jeifhynnxq.mp4
# confidence of prediction: 99.9962329864502
# REAL
# No. of videos processed 3800
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nhveiroygg.mp4
# confidence of prediction: 99.99284744262695
# REAL
# No. of videos processed 3801
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pcffzwvaiv.mp4
# confidence of prediction: 95.03689408302307
# REAL
# No. of videos processed 3802
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ynojgjrciu.mp4
# confidence of prediction: 99.99326467514038
# REAL
# No. of videos processed 3803
# /content/drive/MyDrive/Deepfake/data/test/faces_test/llnsbjgdpp.mp4
# confidence of prediction: 99.99028444290161
# REAL
# No. of videos processed 3804
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fjwgruhuog.mp4
# confidence of prediction: 99.99254941940308
# REAL
# No. of videos processed 3805
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wonvufumrz.mp4
# confidence of prediction: 90.70067405700684
# FAKE
# No. of videos processed 3806
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ffshdaqnkb.mp4
# confidence of prediction: 74.76039528846741
# FAKE
# No. of videos processed 3807
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fxrvoawape.mp4
# confidence of prediction: 86.8747353553772
# REAL
# No. of videos processed 3808
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pczvpkuofn.mp4
# confidence of prediction: 99.98610019683838
# REAL
# No. of videos processed 3809
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eofackxdyv.mp4
# confidence of prediction: 99.99431371688843
# REAL
# No. of videos processed 3810
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gbyhxtuhfi.mp4
# confidence of prediction: 99.96212720870972
# REAL
# No. of videos processed 3811
# /content/drive/MyDrive/Deepfake/data/test/faces_test/sebwfboeho.mp4
# confidence of prediction: 99.98805522918701
# REAL
# No. of videos processed 3812
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xvkflltlbg.mp4
# confidence of prediction: 88.29478621482849
# REAL
# No. of videos processed 3813
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wgsmbdfbsd.mp4
# confidence of prediction: 88.6801540851593
# REAL
# No. of videos processed 3814
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oyysywvoce.mp4
# confidence of prediction: 99.99396800994873
# REAL
# No. of videos processed 3815
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vfmibchajl.mp4
# confidence of prediction: 99.99200105667114
# REAL
# No. of videos processed 3816
# /content/drive/MyDrive/Deepfake/data/test/faces_test/btopkycuih.mp4
# confidence of prediction: 99.97535347938538
# REAL
# No. of videos processed 3817
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qazwolwoky.mp4
# confidence of prediction: 99.9940037727356
# REAL
# No. of videos processed 3818
# /content/drive/MyDrive/Deepfake/data/test/faces_test/phgjjjihuh.mp4
# confidence of prediction: 99.3641197681427
# REAL
# No. of videos processed 3819
# /content/drive/MyDrive/Deepfake/data/test/faces_test/owhnryzuyl.mp4
# confidence of prediction: 72.46099710464478
# FAKE
# No. of videos processed 3820
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wlgidtcnmy.mp4
# confidence of prediction: 58.411818742752075
# FAKE
# No. of videos processed 3821
# /content/drive/MyDrive/Deepfake/data/test/faces_test/onunsaliug.mp4
# confidence of prediction: 99.99359846115112
# REAL
# No. of videos processed 3822
# /content/drive/MyDrive/Deepfake/data/test/faces_test/knzxbsopvk.mp4
# confidence of prediction: 99.99496936798096
# REAL
# No. of videos processed 3823
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hzzvvzkeii.mp4
# confidence of prediction: 99.99303817749023
# REAL
# No. of videos processed 3824
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xnaixrbbju.mp4
# confidence of prediction: 99.9919056892395
# REAL
# No. of videos processed 3825
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bhtytlxyau.mp4
# confidence of prediction: 99.99278783798218
# REAL
# No. of videos processed 3826
# /content/drive/MyDrive/Deepfake/data/test/faces_test/feujfdcfap.mp4
# confidence of prediction: 84.89659428596497
# REAL
# No. of videos processed 3827
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jyupvczkwy.mp4
# confidence of prediction: 99.99288320541382
# REAL
# No. of videos processed 3828
# /content/drive/MyDrive/Deepfake/data/test/faces_test/idntrbscwc.mp4
# confidence of prediction: 99.93796348571777
# REAL
# No. of videos processed 3829
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wdqnhqixqu.mp4
# confidence of prediction: 98.47538471221924
# REAL
# No. of videos processed 3830
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xqjwacyhrg.mp4
# confidence of prediction: 99.98526573181152
# REAL
# No. of videos processed 3831
# /content/drive/MyDrive/Deepfake/data/test/faces_test/negnzmskrx.mp4
# confidence of prediction: 99.99030828475952
# REAL
# No. of videos processed 3832
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dabrmlixvl.mp4
# confidence of prediction: 99.97850060462952
# REAL
# No. of videos processed 3833
# /content/drive/MyDrive/Deepfake/data/test/faces_test/scwvtnqamm.mp4
# confidence of prediction: 99.98936653137207
# REAL
# No. of videos processed 3834
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iebzmcxohx.mp4
# confidence of prediction: 99.03379678726196
# REAL
# No. of videos processed 3835
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vpoeukccfo.mp4
# confidence of prediction: 99.90033507347107
# REAL
# No. of videos processed 3836
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pjdfdxebnm.mp4
# confidence of prediction: 99.9305009841919
# REAL
# No. of videos processed 3837
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lxuosjkowp.mp4
# confidence of prediction: 99.99133348464966
# REAL
# No. of videos processed 3838
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xemfqmmmoj.mp4
# confidence of prediction: 63.64922523498535
# FAKE
# No. of videos processed 3839
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mayrgpjfdn.mp4
# confidence of prediction: 88.91316652297974
# FAKE
# No. of videos processed 3840
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hjzillafzr.mp4
# confidence of prediction: 99.98291730880737
# FAKE
# No. of videos processed 3841
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jvemimcpda.mp4
# confidence of prediction: 99.98725652694702
# REAL
# No. of videos processed 3842
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qxqomyttgy.mp4
# confidence of prediction: 99.9646544456482
# REAL
# No. of videos processed 3843
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rkvajtvvti.mp4
# confidence of prediction: 99.98708963394165
# REAL
# No. of videos processed 3844
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tcdrqavite.mp4
# confidence of prediction: 99.97661709785461
# REAL
# ...
# confidence of prediction: 99.76041913032532
# REAL
# No. of videos processed 4659
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ovudznexmh.mp4
# confidence of prediction: 99.99310970306396
# REAL
# No. of videos processed 4660
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dahitfgojy.mp4
# confidence of prediction: 99.90156888961792
# REAL
# No. of videos processed 4661
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mmiszjerez.mp4
# confidence of prediction: 99.98723268508911
# REAL
# No. of videos processed 4662
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hsluhdwqxj.mp4
# confidence of prediction: 60.315632820129395
# FAKE
# No. of videos processed 4663
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hiaobajdjh.mp4
# confidence of prediction: 99.98192191123962
# REAL
# No. of videos processed 4664
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ostfgauoil.mp4
# confidence of prediction: 99.46921467781067
# REAL
# No. of videos processed 4665
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mmyvyiollv.mp4
# confidence of prediction: 99.99269247055054
# REAL
# No. of videos processed 4666
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qvwbqanceq.mp4
# confidence of prediction: 99.99639987945557
# REAL
# No. of videos processed 4667
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wpuciyzvop.mp4
# confidence of prediction: 66.60314202308655
# FAKE
# No. of videos processed 4668
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lsuwqyyhbs.mp4
# confidence of prediction: 99.9954104423523
# REAL
# No. of videos processed 4669
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dmtbbrxiyh.mp4
# confidence of prediction: 79.95467185974121
# REAL
# No. of videos processed 4670
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eijzzgfroj.mp4
# confidence of prediction: 99.98170733451843
# REAL
# No. of videos processed 4671
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lwiirvdzal.mp4
# confidence of prediction: 99.75146055221558
# REAL
# No. of videos processed 4672
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gzadrozmce.mp4
# confidence of prediction: 71.84632420539856
# REAL
# No. of videos processed 4673
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zmbymhgqhh.mp4
# confidence of prediction: 99.99510049819946
# REAL
# No. of videos processed 4674
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jdooavgiub.mp4
# confidence of prediction: 69.46774125099182
# FAKE
# No. of videos processed 4675
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hrpkmbrlmf.mp4
# confidence of prediction: 99.98605251312256
# REAL
# No. of videos processed 4676
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ladkegghul.mp4
# confidence of prediction: 99.99551773071289
# REAL
# No. of videos processed 4677
# /content/drive/MyDrive/Deepfake/data/test/faces_test/gjobpdsbpd.mp4
# confidence of prediction: 99.99151229858398
# REAL
# No. of videos processed 4678
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tclokkmlnn.mp4
# confidence of prediction: 99.99005794525146
# REAL
# No. of videos processed 4679
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dhafaeocni.mp4
# confidence of prediction: 99.99380111694336
# REAL
# No. of videos processed 4680
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wcifdohbdu.mp4
# confidence of prediction: 98.04487824440002
# FAKE
# No. of videos processed 4681
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uebjcisjwa.mp4
# confidence of prediction: 93.57557892799377
# REAL
# No. of videos processed 4682
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nabzxppyfd.mp4
# confidence of prediction: 99.93439316749573
# REAL
# No. of videos processed 4683
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vfxjxhzfpb.mp4
# confidence of prediction: 78.27114462852478
# REAL
# No. of videos processed 4684
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cnjcxxiogi.mp4
# confidence of prediction: 99.99884366989136
# REAL
# No. of videos processed 4685
# /content/drive/MyDrive/Deepfake/data/test/faces_test/slvqczofrr.mp4
# confidence of prediction: 99.98108744621277
# REAL
# No. of videos processed 4686
# /content/drive/MyDrive/Deepfake/data/test/faces_test/suhxghtiwb.mp4
# confidence of prediction: 99.99423027038574
# REAL
# No. of videos processed 4687
# /content/drive/MyDrive/Deepfake/data/test/faces_test/cgmmvjdrgu.mp4
# confidence of prediction: 99.9496579170227
# REAL
# No. of videos processed 4688
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mqphixpgph.mp4
# confidence of prediction: 99.47876930236816
# REAL
# No. of videos processed 4689
# /content/drive/MyDrive/Deepfake/data/test/faces_test/erjzziiwss.mp4
# confidence of prediction: 74.32193160057068
# FAKE
# No. of videos processed 4690
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uomxypoyiz.mp4
# confidence of prediction: 99.9823272228241
# REAL
# No. of videos processed 4691
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mxdxzoqmlk.mp4
# confidence of prediction: 99.99109506607056
# REAL
# No. of videos processed 4692
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bxpzinvwhy.mp4
# confidence of prediction: 99.9873161315918
# REAL
# No. of videos processed 4693
# /content/drive/MyDrive/Deepfake/data/test/faces_test/njcbwvadpi.mp4
# confidence of prediction: 99.98216032981873
# REAL
# No. of videos processed 4694
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xkxxeicpol.mp4
# confidence of prediction: 99.96013045310974
# REAL
# No. of videos processed 4695
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rbapryahlp.mp4
# confidence of prediction: 99.98304843902588
# REAL
# No. of videos processed 4696
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tugsvbqjhb.mp4
# confidence of prediction: 99.97227787971497
# REAL
# No. of videos processed 4697
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lzmakvfeka.mp4
# confidence of prediction: 99.98593330383301
# REAL
# No. of videos processed 4698
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zeslwymrcy.mp4
# confidence of prediction: 99.98716115951538
# REAL
# No. of videos processed 4699
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qlrzlgzdii.mp4
# confidence of prediction: 99.95948672294617
# REAL
# No. of videos processed 4700
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ammxvdodoj.mp4
# confidence of prediction: 99.99222755432129
# REAL
# No. of videos processed 4701
# /content/drive/MyDrive/Deepfake/data/test/faces_test/metpkhsfnz.mp4
# confidence of prediction: 99.99107122421265
# REAL
# No. of videos processed 4702
# /content/drive/MyDrive/Deepfake/data/test/faces_test/clkxynuwdf.mp4
# confidence of prediction: 99.9385118484497
# REAL
# No. of videos processed 4703
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vyonwdolvl.mp4
# confidence of prediction: 76.85983180999756
# FAKE
# No. of videos processed 4704
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hebnglslkc.mp4
# confidence of prediction: 99.99388456344604
# REAL
# No. of videos processed 4705
# /content/drive/MyDrive/Deepfake/data/test/faces_test/diavvjvaxe.mp4
# confidence of prediction: 99.99251365661621
# REAL
# No. of videos processed 4706
# /content/drive/MyDrive/Deepfake/data/test/faces_test/movblemxop.mp4
# confidence of prediction: 99.99265670776367
# REAL
# No. of videos processed 4707
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jhhjxltzrp.mp4
# confidence of prediction: 99.98278617858887
# REAL
# No. of videos processed 4708
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iqeakgicxq.mp4
# confidence of prediction: 96.64308428764343
# FAKE
# No. of videos processed 4709
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jqaudsztem.mp4
# confidence of prediction: 99.98612403869629
# REAL
# No. of videos processed 4710
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uvlxbivsaj.mp4
# confidence of prediction: 79.31756973266602
# REAL
# No. of videos processed 4711
# /content/drive/MyDrive/Deepfake/data/test/faces_test/euzavbbmzm.mp4
# confidence of prediction: 50.11432766914368
# FAKE
# No. of videos processed 4712
# /content/drive/MyDrive/Deepfake/data/test/faces_test/imezmewzmc.mp4
# confidence of prediction: 97.43824005126953
# REAL
# No. of videos processed 4713
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wggteviwox.mp4
# confidence of prediction: 97.1458911895752
# REAL
# No. of videos processed 4714
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aheipdiaai.mp4
# confidence of prediction: 99.66757297515869
# REAL
# No. of videos processed 4715
# /content/drive/MyDrive/Deepfake/data/test/faces_test/driffbrgwf.mp4
# confidence of prediction: 99.9796450138092
# REAL
# No. of videos processed 4716
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rcngzczbxx.mp4
# confidence of prediction: 98.57355952262878
# REAL
# No. of videos processed 4717
# /content/drive/MyDrive/Deepfake/data/test/faces_test/mdklrhpabg.mp4
# confidence of prediction: 99.98890161514282
# REAL
# No. of videos processed 4718
# /content/drive/MyDrive/Deepfake/data/test/faces_test/fhxdezdkhv.mp4
# confidence of prediction: 99.97712969779968
# REAL
# No. of videos processed 4719
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xqnwztylym.mp4
# confidence of prediction: 99.99468326568604
# REAL
# No. of videos processed 4720
# /content/drive/MyDrive/Deepfake/data/test/faces_test/hzjvykxajp.mp4
# confidence of prediction: 99.9948263168335
# REAL
# No. of videos processed 4721
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jgzsfywvsf.mp4
# confidence of prediction: 99.95985627174377
# REAL
# No. of videos processed 4722
# /content/drive/MyDrive/Deepfake/data/test/faces_test/eunvnqqtzq.mp4
# confidence of prediction: 99.5907187461853
# REAL
# No. of videos processed 4723
# /content/drive/MyDrive/Deepfake/data/test/faces_test/dejyyrfvtl.mp4
# confidence of prediction: 64.42689895629883
# FAKE
# No. of videos processed 4724
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bptiaycugg.mp4
# confidence of prediction: 99.9924898147583
# REAL
# No. of videos processed 4725
# /content/drive/MyDrive/Deepfake/data/test/faces_test/shvrqolzzv.mp4
# confidence of prediction: 99.99053478240967
# REAL
# No. of videos processed 4726
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qefccqgheq.mp4
# confidence of prediction: 99.96966123580933
# REAL
# No. of videos processed 4727
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nxibynvruu.mp4
# confidence of prediction: 99.98577833175659
# REAL
# No. of videos processed 4728
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zptcwzlsbx.mp4
# confidence of prediction: 99.99198913574219
# REAL
# No. of videos processed 4729
# /content/drive/MyDrive/Deepfake/data/test/faces_test/jecwborung.mp4
# confidence of prediction: 99.62716102600098
# REAL
# No. of videos processed 4730
# /content/drive/MyDrive/Deepfake/data/test/faces_test/amdxcpeuvi.mp4
# confidence of prediction: 99.99473094940186
# REAL
# No. of videos processed 4731
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ejsaqwuxrf.mp4
# confidence of prediction: 99.84945058822632
# REAL
# No. of videos processed 4732
# /content/drive/MyDrive/Deepfake/data/test/faces_test/evpdvegqwt.mp4
# confidence of prediction: 99.9895453453064
# REAL
# No. of videos processed 4733
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ifqopwnodw.mp4
# confidence of prediction: 99.98500347137451
# REAL
# No. of videos processed 4734
# /content/drive/MyDrive/Deepfake/data/test/faces_test/esybbvlxmq.mp4
# confidence of prediction: 99.95724558830261
# REAL
# No. of videos processed 4735
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ipciwfuwyn.mp4
# confidence of prediction: 99.98444318771362
# REAL
# No. of videos processed 4736
# /content/drive/MyDrive/Deepfake/data/test/faces_test/qgafgtaszy.mp4
# confidence of prediction: 97.42646813392639
# REAL
# No. of videos processed 4737
# /content/drive/MyDrive/Deepfake/data/test/faces_test/iaqsdziamy.mp4
# confidence of prediction: 99.99672174453735
# REAL
# No. of videos processed 4738
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wvghduqjvu.mp4
# confidence of prediction: 95.89744806289673
# REAL
# No. of videos processed 4739
# /content/drive/MyDrive/Deepfake/data/test/faces_test/berivhgeil.mp4
# confidence of prediction: 99.62384700775146
# FAKE
# No. of videos processed 4740
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pxnejlouuj.mp4
# confidence of prediction: 99.99592304229736
# REAL
# No. of videos processed 4741
# /content/drive/MyDrive/Deepfake/data/test/faces_test/oomrpijbbb.mp4
# confidence of prediction: 99.96188879013062
# FAKE
# No. of videos processed 4742
# /content/drive/MyDrive/Deepfake/data/test/faces_test/tuxcfjvcsp.mp4
# confidence of prediction: 98.63762259483337
# REAL
# No. of videos processed 4743
# /content/drive/MyDrive/Deepfake/data/test/faces_test/uaaohixjzr.mp4
# confidence of prediction: 99.9852180480957
# REAL
# No. of videos processed 4744
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ypmghnabmi.mp4
# confidence of prediction: 99.99268054962158
# REAL
# No. of videos processed 4745
# /content/drive/MyDrive/Deepfake/data/test/faces_test/stkxlbksaq.mp4
# confidence of prediction: 76.84757709503174
# REAL
# No. of videos processed 4746
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pjkkzfcmrq.mp4
# confidence of prediction: 99.87209439277649
# REAL
# No. of videos processed 4747
# /content/drive/MyDrive/Deepfake/data/test/faces_test/ksthbkgeum.mp4
# confidence of prediction: 99.97891783714294
# REAL
# No. of videos processed 4748
# /content/drive/MyDrive/Deepfake/data/test/faces_test/lteqrtjirv.mp4
# confidence of prediction: 99.99493360519409
# REAL
# No. of videos processed 4749
# /content/drive/MyDrive/Deepfake/data/test/faces_test/wkhmbmfuyt.mp4
# confidence of prediction: 63.36057782173157
# FAKE
# No. of videos processed 4750
# /content/drive/MyDrive/Deepfake/data/test/faces_test/pqgssmhtej.mp4
# confidence of prediction: 77.54718065261841
# FAKE
# No. of videos processed 4751
# /content/drive/MyDrive/Deepfake/data/test/faces_test/voefrxkfnp.mp4
# confidence of prediction: 99.99613761901855
# REAL
# No. of videos processed 4752
# /content/drive/MyDrive/Deepfake/data/test/faces_test/bywpqmtlof.mp4
# confidence of prediction: 99.85671043395996
# REAL
# No. of videos processed 4753
# /content/drive/MyDrive/Deepfake/data/test/faces_test/xtqhjqkcoe.mp4
# confidence of prediction: 76.48821473121643
# FAKE
# No. of videos processed 4754
# /content/drive/MyDrive/Deepfake/data/test/faces_test/puxakszicn.mp4
# confidence of prediction: 99.9883770942688
# REAL
# No. of videos processed 4755
# /content/drive/MyDrive/Deepfake/data/test/faces_test/avtdrvnfyh.mp4
# confidence of prediction: 99.86078143119812
# REAL
# No. of videos processed 4756
# /content/drive/MyDrive/Deepfake/data/test/faces_test/kzoijlqubh.mp4
# confidence of prediction: 99.99045133590698
# REAL
# No. of videos processed 4757
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nzgpspbblq.mp4
# confidence of prediction: 61.85299754142761
# FAKE
# No. of videos processed 4758
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vlvieajwjn.mp4
# confidence of prediction: 99.98914003372192
# REAL
# No. of videos processed 4759
# /content/drive/MyDrive/Deepfake/data/test/faces_test/zchwmtppla.mp4
# confidence of prediction: 99.97181296348572
# REAL
# No. of videos processed 4760
# /content/drive/MyDrive/Deepfake/data/test/faces_test/emzlsvtfog.mp4
# confidence of prediction: 90.73911309242249
# REAL
# No. of videos processed 4761
# /content/drive/MyDrive/Deepfake/data/test/faces_test/rpasdekmaf.mp4
# confidence of prediction: 99.98539686203003
# REAL
# No. of videos processed 4762
# /content/drive/MyDrive/Deepfake/data/test/faces_test/olkwmpiyqf.mp4
# confidence of prediction: 99.9543309211731
# REAL
# No. of videos processed 4763
# /content/drive/MyDrive/Deepfake/data/test/faces_test/aqtrruhcat.mp4
# confidence of prediction: 99.99510049819946
# REAL
# No. of videos processed 4764
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nmffpjvask.mp4
# confidence of prediction: 97.27985262870789
# REAL
# No. of videos processed 4765
# /content/drive/MyDrive/Deepfake/data/test/faces_test/vpbhgeavtr.mp4
# confidence of prediction: 99.98342990875244
# REAL
# No. of videos processed 4766
# /content/drive/MyDrive/Deepfake/data/test/faces_test/nirpbnserk.mp4
# confidence of prediction: 99.9911904335022
# REAL
# No. of videos processed 4767
# /content/drive/MyDrive/Deepfake/data/test/faces_test/svraxfiyst.mp4
# confidence of prediction: 68.75900626182556
# REAL
# No. of videos processed 4768

# %%
# replace pred values 0 and 1 to fake and real respectively to create a dataframe
for i in range(len(pred)):
  if pred[i] == 0:
    pred[i] = "Fake"
  elif pred[i] == 1:
    pred[i] = "Real"

# %%
# collect only the names of the files to create a dataframe
vnames = []
for path in video_files:
  vnames.append(os.path.basename(path))

# %%
# true_labels is a list which consists of the original labels of the videos from labels.csv
true_labels = []
for vf in vnames:
  if vf in list(labels['filename']):
    true_labels.append(*list(labels.loc[labels['filename'] == vf, 'label']))
  else:
    print(f'{vf} not in list of videos.')

# %%
# replace 0 and 1 with real and fake in true_labels
for i in range(len(true_labels)):
  if true_labels[i] == 0:
    true_labels[i] = "Real"
  elif true_labels[i] == 1:
    true_labels[i] = "Fake"

# %%
# create a dataframe from vnames, pred, conf, actualLab
predictionDF = pd.DataFrame(list(zip(vnames, pred, conf, true_labels)),
               columns =['Filename', 'Prediction', 'Confidence', 'TrueLabel'])

predictionDF
# Out:
#             Filename Prediction  Confidence TrueLabel
# 0     chsbgqykzl.mp4       Real   99.990618      Real
# 1     yppqnldpow.mp4       Real   99.938464      Fake
# 2     clltctfxgj.mp4       Real   93.289191      Real
# 3     wuzzdfwxlv.mp4       Real   99.933845      Fake
# 4     ppzbhozhns.mp4       Real   99.989927      Real
# ...              ...        ...         ...       ...
# 4763  aqtrruhcat.mp4       Real   99.995100      Real
# 4764  nmffpjvask.mp4       Real   97.279853      Real
# 4765  vpbhgeavtr.mp4       Real   99.983430      Real
# 4766  nirpbnserk.mp4       Real   99.991190      Fake
# 4767  svraxfiyst.mp4       Real   68.759006      Fake
#
# [4768 rows x 4 columns]

# %%
# printing the no of correctly classified files
correct_predictions = list(np.where(predictionDF['Prediction'] == predictionDF['TrueLabel'], True, False)).count(True)
print(f'{correct_predictions} correctly predicted files, out of {predictionDF.shape[0]} video files')
# Out:
# 2678 correctly predicted files, out of 4768 video files

# %%
# calculating the accuracy of the model
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

print("Accuracy of the model(in %):", accuracy_score(true_labels, pred)*100)
# Out:
# Accuracy of the model(in %): 56.16610738255034

# %%
# printing the classification report
target_names = ['Fake', 'Real']
print(classification_report(true_labels, pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.23      0.34      2403
#         Real       0.53      0.90      0.67      2365
#
#     accuracy                           0.56      4768
#    macro avg       0.62      0.56      0.51      4768
# weighted avg       0.62      0.56      0.51      4768

# %%
# printing the confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(true_labels, pred)
plt.show()

# %%
# printing all the values of the confusion matrix
conf_mat = confusion_matrix(true_labels, pred)
print('True positive = ', conf_mat[0][0])
print('False positive = ', conf_mat[0][1])
print('False negative = ', conf_mat[1][0])
print('True negative = ', conf_mat[1][1])
# Out:
# True positive =  548
# False positive =  1855
# False negative =  235
# True negative =  2130

# %%
# function to convert labels into numbers 0 and 1
def convert_labels_to_num(pred_list):
  pred_list_num = []
  for i in range(len(pred_list)):
    if pred_list[i] == "Fake":
      pred_list_num.append(0)
    elif pred_list[i] == "Real":
      pred_list_num.append(1)

  return pred_list_num

# %%
pred_num = convert_labels_to_num(pred)
truelabel_num = convert_labels_to_num(true_labels)

# %%
# Display the roc_auc score of the model
from sklearn.metrics import ConfusionMatrixDisplay, roc_auc_score

roc_auc = roc_auc_score(truelabel_num, pred_num)
print(roc_auc)
# Out:
# 0.564341261231776
